# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('images.jpg',cv2.IMREAD_COLOR)
imgRGB=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img[100:-100,100:-100,0]=0

# %%
img[10,10:]=[255, 255, 255]

# %%
img.shape
# Out:
# (1365, 2048, 3)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
BLUE = [255,0,0]
img1 = cv2.imread('images.jpg')
replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()

# %%
plt.imshow(reflect)
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
img1 = cv2.imread('ml.png')
img2 = cv2.imread('opencv.png')
dst = cv2.addWeighted(img1,0.7,img2,0.3,0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\U209-19\IP2023\ch13.ipynb 셀 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> img1 = cv2.imread('ml.png')
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> img2 = cv2.imread('opencv.png')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> dst = cv2.addWeighted(img1,0.7,img2,0.3,0)
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
plt.imshow(dst)
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\U209-19\IP2023\ch13.ipynb 셀 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> plt.imshow(dst)
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> plt.xticks([]), plt.yticks([])
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> plt.show()
#
# NameError: name 'dst' is not defined

# %%
img1 = cv2.imread('ml.jpg')
img2 = cv2.imread('opencv.png')
# I want to put logo on top-left corner, S

# %%
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\U209-19\IP2023\ch13.ipynb 셀 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> rows,cols,channels = img2.shape
# ----> <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> roi = img1[0:rows, 0:cols ]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

# %%
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\U209-19\IP2023\ch13.ipynb 셀 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
#
# NameError: name 'roi' is not defined

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

# %%
img1 = cv2.imread('ml.jpg')
img2 = cv2.imread('opencv_logo.png')

# %%
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\U209-19\IP2023\ch13.ipynb 셀 16 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> rows,cols,channels = img2.shape
# ----> <a href='vscode-notebook-cell:/c%3A/Users/U209-19/IP2023/ch13.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> roi = img1[0:rows, 0:cols ]
#
# TypeError: 'NoneType' object is not subscriptable
